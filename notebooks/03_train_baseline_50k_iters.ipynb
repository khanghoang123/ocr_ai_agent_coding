# %%
# Install packages not pre-installed on Kaggle
# %pip install -q vietocr jiwer
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.9/133.9 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.0/948.0 kB 23.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 98.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 333.1/333.1 kB 22.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 106.2 MB/s eta 0:00:00
#   Building wheel for gdown (pyproject.toml) ... done
#   Building wheel for prefetch-generator (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires gym<=0.25.2, but you have gym 0.26.2 which is incompatible.
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import re
import time
import random
import shutil
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import jiwer

# ── PIL._util compatibility patch ────────────────────────────────────────────
try:
    from PIL._util import is_directory as _test_pil
except ImportError:
    import os as _os
    from PIL import _util as _pil_util
    if not hasattr(_pil_util, 'is_path'):
        _pil_util.is_path = lambda f: isinstance(f, (bytes, str, _os.PathLike))
    if not hasattr(_pil_util, 'is_directory'):
        _pil_util.is_directory = lambda f: (isinstance(f, (bytes, str, _os.PathLike)) and _os.path.isdir(f))
    print('Applied PIL._util compatibility patch.')

from PIL import Image
import torch

# ── NumPy 2.0 compatibility patches ─────────────────────────────────────────
if not hasattr(np, 'sctypes'):
    np.sctypes = {
        'int': [np.int8, np.int16, np.int32, np.int64],
        'uint': [np.uint8, np.uint16, np.uint32, np.uint64],
        'float': [np.float16, np.float32, np.float64],
        'complex': [np.complex64, np.complex128],
        'others': [np.bool_, np.bytes_, np.str_, np.object_, np.void, np.datetime64, np.timedelta64],
    }
if not hasattr(np, 'bool'): np.bool = bool
if not hasattr(np, 'int'): np.int = int
if not hasattr(np, 'float'): np.float = float

from vietocr.tool.config import Cfg
from vietocr.tool.predictor import Predictor
from vietocr.model.trainer import Trainer

warnings.filterwarnings('ignore')
print(f'Torch version: {torch.__version__}')
print('All imports OK.')
# Out:
# Applied PIL._util compatibility patch.
# Torch version: 2.10.0+cu128
# All imports OK.

# %%
seed = 59
KAGGLE_ROOT = '/kaggle/input/datasets/ghtgfuiss123/vn-handwritten-ocr-dataset'

CONFIG = {
    # ── Paths ─────────────────────────────────────────────────────────────────
    'train_path'    : f'{KAGGLE_ROOT}/data/data/processed/train_line.txt',
    'val_path'      : f'{KAGGLE_ROOT}/data/data/processed/val.txt',
    'test_path'     : f'{KAGGLE_ROOT}/data/data/processed/test.txt',
    'metadata_path' : f'{KAGGLE_ROOT}/data/data/processed/split_metadata.json',
    'checkpoint_dir': '/kaggle/working/models/baseline/',

    # ── Data ──────────────────────────────────────────────────────────────────
    'image_root'    : f'{KAGGLE_ROOT}/Dataset/Dataset/data',

    'image_height'   : 32,
    'image_max_width': 690,
    'image_min_width': 32,
    'max_label_len'  : 180,
    'grayscale'      : True,

    # ── Model ─────────────────────────────────────────────────────────────────
    'backbone'  : 'vgg19_bn',
    'pretrained': True,

    # ── Training ──────────────────────────────────────────────────────────────
    'batch_size' : 32,
    'max_lr'     : 3e-4,
    'total_iters': 50000,
    'valid_every': 500,
    'log_every'  : 200,
    'device'     : 'cuda:0',
}

print('CONFIG loaded.')
os.makedirs(CONFIG['checkpoint_dir'], exist_ok=True)
# Out:
# CONFIG loaded.

# %% [markdown]
# ## 1. Load Processed Data

# %%
def read_annotation_file(filepath):
    """Read a tab-separated annotation file: <image_path>\\t<transcription>"""
    entries = []
    with open(filepath, "r", encoding="utf-8") as f:
        for line_num, line in enumerate(f, 1):
            line = line.rstrip("\n")
            if not line.strip():
                continue
            parts = line.split("\t", maxsplit=1)
            if len(parts) != 2:
                print(f"WARNING: Skipping malformed line {line_num} in {filepath}")
                continue
            entries.append((parts[0].strip(), parts[1].strip()))
    return entries

# %%
def filter_by_label_len(entries, max_len):
    """Filter out entries where len(transcription) > max_len."""
    kept = [(img, txt) for img, txt in entries if len(txt) <= max_len]
    return kept, len(entries) - len(kept)

# %%
# ---- Load annotation files ----
train_data = read_annotation_file(CONFIG["train_path"])
val_data = read_annotation_file(CONFIG["val_path"])
test_data = read_annotation_file(CONFIG["test_path"])

print(f"Training text-lines : {len(train_data):,}")
print(f"Val text-lines       : {len(val_data):,}")
print(f"Test samples  : {len(test_data):,}")

# ---- max_label_len guard ----
max_len = CONFIG["max_label_len"]
train_data, train_dropped = filter_by_label_len(train_data, max_len)
val_data, val_dropped = filter_by_label_len(val_data, max_len)
test_data, test_dropped = filter_by_label_len(test_data, max_len)


print(f"\nmax_label_len guard ({max_len}):")
print(f"  Train dropped : {train_dropped:,}")
print(f"  Val dropped   : {val_dropped:,}")
print(f"  Test dropped  : {test_dropped:,}")
print(f"\nSau khi lọc:")
print(f"  Train samples : {len(train_data):,}")
print(f"  Val samples   : {len(val_data):,}")
print(f"  Test samples  : {len(test_data):,}")

print("\nSample annotations (first 3):")
for img, txt in train_data[:3]:
    print(f"  {img}  ->  {txt[:80]}{'...' if len(txt) > 80 else ''}")
# Out:
# Training text-lines : 13,090
# Val text-lines       : 1,636
# Test samples  : 1,637
#
# max_label_len guard (180):
#   Train dropped : 0
#   Val dropped   : 0
#   Test dropped  : 0
#
# Sau khi lọc:
#   Train samples : 13,090
#   Val samples   : 1,636
#   Test samples  : 1,637
#
# Sample annotations (first 3):
#   data/UIT_HWDB_line_flat__40_4.jpg  ->  chưa di dời. Như vậy, trước thời điểm cấm xe tải nặng lưu thông ở nội ô vào ban
#   data/VNOnDB_line__20160604_0199_25463_tg_0_3.png  ->  chiều 15 - 3 - 2004. Theo thông tin ban đầu, phía nạn nhân khai nhận với một số ...
#   data/VNOnDB_line__20151111_0050_25439_2_tg_4_0.png  ->  Đề nghị anh Đại liên hệ với chúng tôi : Công ty Xây lắp & vật tư xây

# %% [markdown]
# ## 2. Prepare Annotation Files

# %%
def write_annotation_file(entries, image_root, output_path):
    """Write entries to VietOCR annotation file with absolute image paths."""
    abs_root = os.path.abspath(image_root)
    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    with open(output_path, "w", encoding="utf-8") as f:
        for img_path, transcript in entries:
            if img_path.startswith('data/'):
                basename = img_path[len('data/'):]
                abs_img = os.path.join(abs_root, basename)
            else:
                abs_img = os.path.join(abs_root, img_path)
            f.write(f"{abs_img}\t{transcript}\n")
    return output_path

# %%
# On Kaggle, input is read-only. We save annotations to /kaggle/working/annotations/
working_annot_dir = '/kaggle/working/annotations/'
os.makedirs(working_annot_dir, exist_ok=True)

train_annotation_path = os.path.join(working_annot_dir, 'train_annotation.txt')
val_annotation_path = os.path.join(working_annot_dir, 'val_annotation.txt')

write_annotation_file(train_data, CONFIG['image_root'], train_annotation_path)
write_annotation_file(val_data, CONFIG['image_root'], val_annotation_path)

print(f'Training annotation  : {train_annotation_path}')
print(f'Validation annotation: {val_annotation_path}')
# Out:
# Training annotation  : /kaggle/working/annotations/train_annotation.txt
# Validation annotation: /kaggle/working/annotations/val_annotation.txt

# %% [markdown]
# ## 3. Build VietOCR Config

# %%
config = Cfg.load_config_from_name("vgg_seq2seq")

# %%
config['trainer']
# Out:
# {'batch_size': 32,
#  'print_every': 200,
#  'valid_every': 4000,
#  'iters': 100000,
#  'export': './weights/transformerocr.pth',
#  'checkpoint': './checkpoint/transformerocr_checkpoint.pth',
#  'log': './train.log',
#  'metrics': None}

# %%
# Dataset
config["dataset"]["data_root"] = ""  # Empty for absolute paths
config["dataset"]["name"] = "vn_handwritten_ocr"
config["dataset"]["train_annotation"] = os.path.abspath(train_annotation_path)
config["dataset"]["valid_annotation"] = os.path.abspath(val_annotation_path)
config["dataset"]["image_height"] = CONFIG["image_height"]
config["dataset"]["image_max_width"] = CONFIG["image_max_width"]
config["dataset"]["image_min_width"] = CONFIG["image_min_width"]

# Training hyperparameters
config["trainer"]["batch_size"] = CONFIG["batch_size"]
config["trainer"]["iters"] = CONFIG["total_iters"]
config["trainer"]["valid_every"] = CONFIG["valid_every"]
config["trainer"]["print_every"] = CONFIG["log_every"]
config["optimizer"]["max_lr"] = CONFIG["max_lr"]

# Checkpoint / logging
checkpoint_dir_abs = os.path.abspath(CONFIG["checkpoint_dir"])
os.makedirs(checkpoint_dir_abs, exist_ok=True)

config["trainer"]["export"] = os.path.join(checkpoint_dir_abs, "best_model.pth")
config["trainer"]["log"] = os.path.join(checkpoint_dir_abs, "training_log")
config["trainer"]["checkpoint"] = os.path.join(checkpoint_dir_abs, "last_checkpoint.pth")
# Device
config["device"] = CONFIG["device"]

# Print summary
print("=" * 60)
print("VietOCR Configuration Summary")
print("=" * 60)
for section_name in ["dataset", "transformer", "optimizer", "trainer"]:
    if section_name in config:
        print(f"\n[{section_name}]")
        section = config[section_name]
        if isinstance(section, dict):
            for k, v in section.items():
                print(f"  {k}: {v}")
        else:
            print(f"  {section}")
print(f"\nbackbone: {config.get('backbone', 'N/A')}")
print(f"device  : {config.get('device', 'N/A')}")
print("=" * 60)
# Out:
# ============================================================
# VietOCR Configuration Summary
# ============================================================
#
# [dataset]
#   name: vn_handwritten_ocr
#   data_root:
#   train_annotation: /kaggle/working/annotations/train_annotation.txt
#   valid_annotation: /kaggle/working/annotations/val_annotation.txt
#   image_height: 32
#   image_min_width: 32
#   image_max_width: 690
#
# [transformer]
#   encoder_hidden: 256
#   decoder_hidden: 256
#   img_channel: 256
#   decoder_embedded: 256
#   dropout: 0.1
#
# [optimizer]
#   max_lr: 0.0003
#   pct_start: 0.1
#
# [trainer]
#   batch_size: 32
#   print_every: 200
#   valid_every: 500
#   iters: 50000
#   export: /kaggle/working/models/baseline/best_model.pth
#   checkpoint: /kaggle/working/models/baseline/last_checkpoint.pth
#   log: /kaggle/working/models/baseline/training_log
#   metrics: None
#
# backbone: vgg19_bn
# device  : cuda:0
# ============================================================

# %% [markdown]
# ## 4. Initialize Trainer

# %%
# Removed: Unnecessary train.txt overwrite
# Data already properly formatted in train_annotation.txt

# %%
import glob
import shutil
import os

def cleanup_lmdb_cache(patterns):
    removed = []
    for pattern in patterns:
        for path in glob.glob(pattern):
            if os.path.isdir(path):
                shutil.rmtree(path, ignore_errors=True)
                removed.append(path)
            elif os.path.isfile(path):
                os.remove(path)
                removed.append(path)
    return removed

# Remove stale VietOCR LMDB caches before Trainer() creates them.
# Corrupted LMDB usually appears after an interrupted previous run.
lmdb_patterns = [
    "train_data*",
    "valid_data*",
    "train_*",
    "valid_*",
    "/content/train_data*",
    "/content/valid_data*",
    "/content/train_*",
    "/content/valid_*",
    "/tmp/train_data*",
    "/tmp/valid_data*",
    "/tmp/train_*",
    "/tmp/valid_*",
]

removed = cleanup_lmdb_cache(lmdb_patterns)
if removed:
    print("Removed stale LMDB cache paths:")
    for path in removed:
        print(f"  - {path}")
else:
    print("No stale LMDB cache paths found.")

# Use a unique cache name to avoid colliding with previous interrupted runs.
config["dataset"]["name"] = f"vn_handwritten_ocr_seed_{seed}"
print(f'Dataset LMDB cache name: {config["dataset"]["name"]}')
# Out:
# No stale LMDB cache paths found.
# Dataset LMDB cache name: vn_handwritten_ocr_seed_59

# %%
# Force cleanup old LMDB caches (may have the cnt-1 bug)
print("🗑️  Cleaning up old LMDB caches...")
import glob
import shutil

lmdb_patterns = [
    "train_vn_handwritten_ocr*",
    "valid_vn_handwritten_ocr*",
    "train_data*",
    "valid_data*"
]

removed_count = 0
for pattern in lmdb_patterns:
    for path in glob.glob(pattern):
        if os.path.isdir(path):
            print(f"   Removing: {path}")
            shutil.rmtree(path, ignore_errors=True)
            removed_count += 1

if removed_count > 0:
    print(f"✓ Removed {removed_count} old LMDB cache(s)")
else:
    print("✓ No old caches found")

print()

class Custom_Trainer(Trainer):
    def __init__(self, config, pretrained=True):
        super().__init__(config, pretrained)

    def train(self):
        total_loss = 0
        total_loader_time = 0
        total_gpu_time = 0
        best_acc = 0

        data_iter = iter(self.train_gen)

        try:
            for i in range(self.num_iters):
                self.iter += 1

                start = time.time()

                try:
                    batch = next(data_iter)
                except StopIteration:
                    data_iter = iter(self.train_gen)
                    try:
                        batch = next(data_iter)
                    except StopIteration:
                        print(f"\nDataset exhausted at iteration {self.iter}/{self.num_iters}")
                        break

                total_loader_time += time.time() - start

                start = time.time()
                loss = self.step(batch)
                total_gpu_time += time.time() - start

                total_loss += loss
                self.train_losses.append((self.iter, loss))

                if self.iter % self.print_every == 0:
                    info = (
                        "iter: {:06d} - train loss: {:.3f} - lr: {:.2e} - load time: {:.2f} - gpu time: {:.2f}".format(
                            self.iter,
                            total_loss / self.print_every,
                            self.optimizer.param_groups[0]["lr"],
                            total_loader_time,
                            total_gpu_time,
                        )
                    )

                    total_loss = 0
                    total_loader_time = 0
                    total_gpu_time = 0

                    print(info)
                    self.logger.log(info)

                    # SAVE CHECKPOINT
                    if self.checkpoint:
                        print(">>> Auto-saving checkpoint...")
                        self.save_checkpoint(self.checkpoint)

                if self.valid_annotation and self.iter % self.valid_every == 0:
                    val_loss = self.validate()
                    acc_full_seq, acc_per_char = self.precision(self.metrics)

                    info = (
                        "iter: {:06d} - valid loss: {:.3f} - acc full seq: {:.4f} - acc per char: {:.4f}".format(
                            self.iter, val_loss, acc_full_seq, acc_per_char
                        )
                    )
                    print(info)
                    self.logger.log(info)

                    if acc_full_seq > best_acc:
                        self.save_weights(self.export_weights)
                        best_acc = acc_full_seq

        finally:
            # 🔥 SAVE khi bị kill
            if self.checkpoint:
                try:
                    print(">>> Saving final checkpoint...")
                    self.save_checkpoint(self.checkpoint)
                except Exception as e:
                    print("Failed to save final checkpoint:", e)
# Out:
# 🗑️  Cleaning up old LMDB caches...
# ✓ No old caches found

# %%
import shutil
import glob
import time

# ── Strong LMDB Cleanup ──────────────────────────────────────────────────
print('🧹  Strong LMDB Cache Cleanup...')
for d in glob.glob('train_*') + glob.glob('valid_*'):
    if os.path.exists(d):
        print(f'   Removing {d}')
        shutil.rmtree(d, ignore_errors=True)

# Use a timestamp-based unique name to avoid cache collision
config['dataset']['name'] = f'baseline_ocr_{int(time.time())}'
print(f'Using unique dataset name: {config["dataset"]["name"]}')

trainer = Custom_Trainer(config, pretrained=CONFIG["pretrained"])

# Validate dataset is loaded
try:
    dataset_size = len(trainer.train_gen.dataset)
    print(f"✓ Training dataset loaded: {dataset_size:,} samples")
    if dataset_size == 0:
        raise ValueError("Training dataset is empty! Check data paths and LMDB cache.")
except Exception as e:
    print(f"✗ Error checking dataset: {e}")
    raise

total_params = sum(p.numel() for p in trainer.model.parameters())
trainable_params = sum(p.numel() for p in trainer.model.parameters() if p.requires_grad)

print(f"Total parameters     : {total_params:,}")
print(f"Trainable parameters : {trainable_params:,}")
print(f"Frozen parameters    : {total_params - trainable_params:,}")
print(f"\nModel exported to    : {config['trainer']['export']}")
print(f"Training log at      : {config['trainer']['log']}")
print(f"Last checkpoint at   : {config['trainer']['checkpoint']}")
# Out:
# 🧹  Strong LMDB Cache Cleanup...
# Using unique dataset name: baseline_ocr_1776669864
# Downloading: "https://download.pytorch.org/models/vgg19_bn-c79401a0.pth" to /root/.cache/torch/hub/checkpoints/vgg19_bn-c79401a0.pth
# 100%|██████████| 548M/548M [00:02<00:00, 226MB/s]
# 10935it [00:09, 1108.60it/s]
# Create train_baseline_ocr_1776669864: 100%|███████████████████| 13090/13090 [03:10<00:00, 68.81it/s]
# Created dataset with 13089 samples
# train_baseline_ocr_1776669864 build cluster: 100%|████████| 13089/13089 [00:00<00:00, 219809.76it/s]
# Create valid_baseline_ocr_1776669864: 100%|████████████████████| 1636/1636 [00:14<00:00, 109.46it/s]
# Created dataset with 1635 samples
# valid_baseline_ocr_1776669864 build cluster: 100%|██████████| 1635/1635 [00:00<00:00, 188067.33it/s]
# ✓ Training dataset loaded: 13,089 samples
# Total parameters     : 22,371,113
# Trainable parameters : 22,371,113
# Frozen parameters    : 0
#
# Model exported to    : /kaggle/working/models/baseline/best_model.pth
# Training log at      : /kaggle/working/models/baseline/training_log
# Last checkpoint at   : /kaggle/working/models/baseline/last_checkpoint.pth

# %% [markdown]
# ## 5. Training

# %%
print("Starting training...")
print(f"  Total iterations : {CONFIG['total_iters']:,}")
print(f"  Batch size       : {CONFIG['batch_size']}")
print(f"  Validate every   : {CONFIG['valid_every']:,} iters")
print(f"  Log every        : {CONFIG['log_every']} iters")
print(f"  Device           : {CONFIG['device']}")
print("=" * 60)

try:
    trainer.train()
    print("\nTraining completed successfully!")
except KeyboardInterrupt:
    print("\nTraining interrupted by user. Last checkpoint saved.")
    trainer.save_checkpoint(config["trainer"]["checkpoint"])
except Exception as e:
    print(f"\nTraining failed with error: {e}")
    raise
# Out:
# Starting training...
#   Total iterations : 50,000
#   Batch size       : 32
#   Validate every   : 500 iters
#   Log every        : 200 iters
#   Device           : cuda:0
# ============================================================
# iter: 000200 - train loss: 1.366 - lr: 1.31e-05 - load time: 0.78 - gpu time: 148.05
# >>> Auto-saving checkpoint...
# iter: 000400 - train loss: 1.166 - lr: 1.65e-05 - load time: 0.77 - gpu time: 150.39
# >>> Auto-saving checkpoint...
# iter: 000500 - valid loss: 1.009 - acc full seq: 0.0011 - acc per char: 0.4576
# iter: 000600 - train loss: 1.107 - lr: 2.21e-05 - load time: 0.07 - gpu time: 157.29
# >>> Auto-saving checkpoint...
# iter: 000800 - train loss: 1.031 - lr: 2.98e-05 - load time: 0.86 - gpu time: 159.02
# >>> Auto-saving checkpoint...
# iter: 001000 - train loss: 0.996 - lr: 3.95e-05 - load time: 0.07 - gpu time: 156.01
# >>> Auto-saving checkpoint...
# iter: 001000 - valid loss: 0.928 - acc full seq: 0.0234 - acc per char: 0.5542
# iter: 001200 - train loss: 0.965 - lr: 5.10e-05 - load time: 0.44 - gpu time: 157.26
# >>> Auto-saving checkpoint...
# iter: 001400 - train loss: 0.940 - lr: 6.42e-05 - load time: 0.07 - gpu time: 154.29
# >>> Auto-saving checkpoint...
# iter: 001500 - valid loss: 0.881 - acc full seq: 0.0335 - acc per char: 0.6274
# iter: 001600 - train loss: 0.900 - lr: 7.89e-05 - load time: 0.86 - gpu time: 156.32
# >>> Auto-saving checkpoint...
# iter: 001800 - train loss: 0.899 - lr: 9.47e-05 - load time: 0.06 - gpu time: 159.34
# >>> Auto-saving checkpoint...
# iter: 002000 - train loss: 0.855 - lr: 1.12e-04 - load time: 0.53 - gpu time: 159.62
# >>> Auto-saving checkpoint...
# iter: 002000 - valid loss: 0.833 - acc full seq: 0.0670 - acc per char: 0.6729
# iter: 002200 - train loss: 0.853 - lr: 1.29e-04 - load time: 0.07 - gpu time: 153.68
# >>> Auto-saving checkpoint...
# iter: 002400 - train loss: 0.842 - lr: 1.47e-04 - load time: 0.80 - gpu time: 155.21
# >>> Auto-saving checkpoint...
# iter: 002500 - valid loss: 0.815 - acc full seq: 0.0859 - acc per char: 0.7127
# iter: 002600 - train loss: 0.834 - lr: 1.65e-04 - load time: 0.06 - gpu time: 159.74
# >>> Auto-saving checkpoint...
# iter: 002800 - train loss: 0.825 - lr: 1.83e-04 - load time: 0.73 - gpu time: 160.08
# >>> Auto-saving checkpoint...
# iter: 003000 - train loss: 0.805 - lr: 2.01e-04 - load time: 0.07 - gpu time: 153.65
# >>> Auto-saving checkpoint...
# iter: 003000 - valid loss: 0.801 - acc full seq: 0.1150 - acc per char: 0.7478
# iter: 003200 - train loss: 0.795 - lr: 2.17e-04 - load time: 0.48 - gpu time: 158.86
# >>> Auto-saving checkpoint...
# iter: 003400 - train loss: 0.802 - lr: 2.33e-04 - load time: 0.69 - gpu time: 155.33
# >>> Auto-saving checkpoint...
# iter: 003500 - valid loss: 0.783 - acc full seq: 0.1417 - acc per char: 0.7388
# iter: 003600 - train loss: 0.777 - lr: 2.48e-04 - load time: 0.07 - gpu time: 155.65
# >>> Auto-saving checkpoint...
# iter: 003800 - train loss: 0.785 - lr: 2.61e-04 - load time: 0.79 - gpu time: 157.26
# >>> Auto-saving checkpoint...
# iter: 004000 - train loss: 0.774 - lr: 2.73e-04 - load time: 0.06 - gpu time: 158.62
# >>> Auto-saving checkpoint...
# iter: 004000 - valid loss: 0.772 - acc full seq: 0.1830 - acc per char: 0.7852
# iter: 004200 - train loss: 0.775 - lr: 2.82e-04 - load time: 0.50 - gpu time: 154.43
# >>> Auto-saving checkpoint...
# iter: 004400 - train loss: 0.754 - lr: 2.90e-04 - load time: 0.07 - gpu time: 160.91
# >>> Auto-saving checkpoint...
# iter: 004500 - valid loss: 0.755 - acc full seq: 0.1819 - acc per char: 0.7803
# iter: 004600 - train loss: 0.770 - lr: 2.95e-04 - load time: 0.71 - gpu time: 158.82
# >>> Auto-saving checkpoint...
# iter: 004800 - train loss: 0.745 - lr: 2.99e-04 - load time: 0.07 - gpu time: 155.15
# >>> Auto-saving checkpoint...
# iter: 005000 - train loss: 0.743 - lr: 3.00e-04 - load time: 0.75 - gpu time: 156.77
# >>> Auto-saving checkpoint...
# iter: 005000 - valid loss: 0.761 - acc full seq: 0.1998 - acc per char: 0.7887
# iter: 005200 - train loss: 0.742 - lr: 3.00e-04 - load time: 0.07 - gpu time: 157.11
# >>> Auto-saving checkpoint...
# iter: 005400 - train loss: 0.727 - lr: 3.00e-04 - load time: 0.61 - gpu time: 156.16
# >>> Auto-saving checkpoint...
# iter: 005500 - valid loss: 0.759 - acc full seq: 0.2400 - acc per char: 0.8070
# iter: 005600 - train loss: 0.743 - lr: 3.00e-04 - load time: 0.07 - gpu time: 157.42
# >>> Auto-saving checkpoint...
# iter: 005800 - train loss: 0.740 - lr: 3.00e-04 - load time: 0.41 - gpu time: 157.96
# >>> Auto-saving checkpoint...
# iter: 006000 - train loss: 0.732 - lr: 3.00e-04 - load time: 0.07 - gpu time: 156.68
# >>> Auto-saving checkpoint...
# iter: 006000 - valid loss: 0.750 - acc full seq: 0.2333 - acc per char: 0.8037
# iter: 006200 - train loss: 0.735 - lr: 2.99e-04 - load time: 0.79 - gpu time: 159.80
# >>> Auto-saving checkpoint...
# iter: 006400 - train loss: 0.718 - lr: 2.99e-04 - load time: 0.63 - gpu time: 153.76
# >>> Auto-saving checkpoint...
# iter: 006500 - valid loss: 0.737 - acc full seq: 0.2489 - acc per char: 0.8131
# iter: 006600 - train loss: 0.724 - lr: 2.99e-04 - load time: 0.07 - gpu time: 159.93
# >>> Auto-saving checkpoint...
# iter: 006800 - train loss: 0.726 - lr: 2.99e-04 - load time: 0.82 - gpu time: 153.55
# >>> Auto-saving checkpoint...
# iter: 007000 - train loss: 0.713 - lr: 2.99e-04 - load time: 0.08 - gpu time: 156.96
# >>> Auto-saving checkpoint...
# iter: 007000 - valid loss: 0.734 - acc full seq: 0.2411 - acc per char: 0.8147
# iter: 007200 - train loss: 0.719 - lr: 2.98e-04 - load time: 0.75 - gpu time: 156.91
# >>> Auto-saving checkpoint...
# iter: 007400 - train loss: 0.712 - lr: 2.98e-04 - load time: 0.07 - gpu time: 156.25
# >>> Auto-saving checkpoint...
# iter: 007500 - valid loss: 0.740 - acc full seq: 0.2701 - acc per char: 0.8121
# iter: 007600 - train loss: 0.709 - lr: 2.98e-04 - load time: 0.81 - gpu time: 154.35
# >>> Auto-saving checkpoint...
# iter: 007800 - train loss: 0.713 - lr: 2.97e-04 - load time: 0.07 - gpu time: 158.88
# >>> Auto-saving checkpoint...
# iter: 008000 - train loss: 0.705 - lr: 2.97e-04 - load time: 0.84 - gpu time: 155.88
# >>> Auto-saving checkpoint...
# iter: 008000 - valid loss: 0.732 - acc full seq: 0.2746 - acc per char: 0.8176
# iter: 008200 - train loss: 0.702 - lr: 2.96e-04 - load time: 0.07 - gpu time: 156.78
# >>> Auto-saving checkpoint...
# iter: 008400 - train loss: 0.711 - lr: 2.96e-04 - load time: 0.74 - gpu time: 159.81
# >>> Auto-saving checkpoint...
# iter: 008500 - valid loss: 0.738 - acc full seq: 0.2533 - acc per char: 0.8171
# iter: 008600 - train loss: 0.706 - lr: 2.95e-04 - load time: 0.07 - gpu time: 156.32
# >>> Auto-saving checkpoint...
# iter: 008800 - train loss: 0.698 - lr: 2.95e-04 - load time: 0.42 - gpu time: 154.17
# >>> Auto-saving checkpoint...
# iter: 009000 - train loss: 0.707 - lr: 2.94e-04 - load time: 0.07 - gpu time: 158.23
# >>> Auto-saving checkpoint...
# iter: 009000 - valid loss: 0.732 - acc full seq: 0.2757 - acc per char: 0.8185
# iter: 009200 - train loss: 0.697 - lr: 2.94e-04 - load time: 0.85 - gpu time: 160.14
# >>> Auto-saving checkpoint...
# iter: 009400 - train loss: 0.702 - lr: 2.93e-04 - load time: 0.06 - gpu time: 155.21
# >>> Auto-saving checkpoint...
# iter: 009500 - valid loss: 0.726 - acc full seq: 0.3147 - acc per char: 0.8403
# iter: 009600 - train loss: 0.703 - lr: 2.92e-04 - load time: 0.69 - gpu time: 159.96
# >>> Auto-saving checkpoint...
# iter: 009800 - train loss: 0.690 - lr: 2.92e-04 - load time: 0.52 - gpu time: 154.01
# >>> Auto-saving checkpoint...
# iter: 010000 - train loss: 0.697 - lr: 2.91e-04 - load time: 0.07 - gpu time: 155.15
# >>> Auto-saving checkpoint...
# iter: 010000 - valid loss: 0.745 - acc full seq: 0.3002 - acc per char: 0.8291
# iter: 010200 - train loss: 0.694 - lr: 2.90e-04 - load time: 0.38 - gpu time: 158.09
# >>> Auto-saving checkpoint...
# iter: 010400 - train loss: 0.685 - lr: 2.89e-04 - load time: 0.07 - gpu time: 151.71
# >>> Auto-saving checkpoint...
# iter: 010500 - valid loss: 0.725 - acc full seq: 0.2645 - acc per char: 0.8260
# iter: 010600 - train loss: 0.701 - lr: 2.89e-04 - load time: 0.46 - gpu time: 162.86
# >>> Auto-saving checkpoint...
# iter: 010800 - train loss: 0.686 - lr: 2.88e-04 - load time: 0.07 - gpu time: 157.40
# >>> Auto-saving checkpoint...
# iter: 011000 - train loss: 0.685 - lr: 2.87e-04 - load time: 0.86 - gpu time: 154.36
# >>> Auto-saving checkpoint...
# iter: 011000 - valid loss: 0.728 - acc full seq: 0.2891 - acc per char: 0.8186
# iter: 011200 - train loss: 0.693 - lr: 2.86e-04 - load time: 0.06 - gpu time: 156.62
# >>> Auto-saving checkpoint...
# iter: 011400 - train loss: 0.693 - lr: 2.85e-04 - load time: 0.70 - gpu time: 160.10
# >>> Auto-saving checkpoint...
# iter: 011500 - valid loss: 0.725 - acc full seq: 0.3158 - acc per char: 0.8340
# iter: 011600 - train loss: 0.686 - lr: 2.84e-04 - load time: 0.07 - gpu time: 155.06
# >>> Auto-saving checkpoint...
# iter: 011800 - train loss: 0.689 - lr: 2.83e-04 - load time: 0.93 - gpu time: 160.03
# >>> Auto-saving checkpoint...
# iter: 012000 - train loss: 0.678 - lr: 2.82e-04 - load time: 0.07 - gpu time: 154.01
# >>> Auto-saving checkpoint...
# iter: 012000 - valid loss: 0.733 - acc full seq: 0.3214 - acc per char: 0.8377
# iter: 012200 - train loss: 0.688 - lr: 2.81e-04 - load time: 0.69 - gpu time: 158.45
# >>> Auto-saving checkpoint...
# iter: 012400 - train loss: 0.682 - lr: 2.80e-04 - load time: 0.07 - gpu time: 156.16
# >>> Auto-saving checkpoint...
# iter: 012500 - valid loss: 0.717 - acc full seq: 0.3158 - acc per char: 0.8309
# iter: 012600 - train loss: 0.692 - lr: 2.79e-04 - load time: 0.74 - gpu time: 160.91
# >>> Auto-saving checkpoint...
# iter: 012800 - train loss: 0.674 - lr: 2.78e-04 - load time: 0.76 - gpu time: 153.71
# >>> Auto-saving checkpoint...
# iter: 013000 - train loss: 0.680 - lr: 2.77e-04 - load time: 0.07 - gpu time: 154.90
# >>> Auto-saving checkpoint...
# iter: 013000 - valid loss: 0.725 - acc full seq: 0.3259 - acc per char: 0.8438
# iter: 013200 - train loss: 0.678 - lr: 2.76e-04 - load time: 0.41 - gpu time: 158.87
# >>> Auto-saving checkpoint...
# iter: 013400 - train loss: 0.681 - lr: 2.75e-04 - load time: 0.07 - gpu time: 154.95
# >>> Auto-saving checkpoint...
# iter: 013500 - valid loss: 0.719 - acc full seq: 0.3281 - acc per char: 0.8487
# iter: 013600 - train loss: 0.678 - lr: 2.74e-04 - load time: 0.95 - gpu time: 155.79
# >>> Auto-saving checkpoint...
# iter: 013800 - train loss: 0.682 - lr: 2.73e-04 - load time: 0.07 - gpu time: 157.64
# >>> Auto-saving checkpoint...
# iter: 014000 - train loss: 0.681 - lr: 2.71e-04 - load time: 0.92 - gpu time: 156.81
# >>> Auto-saving checkpoint...
# iter: 014000 - valid loss: 0.723 - acc full seq: 0.3471 - acc per char: 0.8353
# iter: 014200 - train loss: 0.677 - lr: 2.70e-04 - load time: 0.07 - gpu time: 158.37
# >>> Auto-saving checkpoint...
# iter: 014400 - train loss: 0.667 - lr: 2.69e-04 - load time: 1.08 - gpu time: 150.68
# >>> Auto-saving checkpoint...
# iter: 014500 - valid loss: 0.724 - acc full seq: 0.3125 - acc per char: 0.8343
# iter: 014600 - train loss: 0.681 - lr: 2.68e-04 - load time: 0.06 - gpu time: 163.78
# >>> Auto-saving checkpoint...
# iter: 014800 - train loss: 0.674 - lr: 2.66e-04 - load time: 0.55 - gpu time: 157.92
# >>> Auto-saving checkpoint...
# iter: 015000 - train loss: 0.680 - lr: 2.65e-04 - load time: 0.08 - gpu time: 153.67
# >>> Auto-saving checkpoint...
# iter: 015000 - valid loss: 0.719 - acc full seq: 0.3181 - acc per char: 0.8337
# iter: 015200 - train loss: 0.677 - lr: 2.64e-04 - load time: 0.86 - gpu time: 157.59
# >>> Auto-saving checkpoint...
# iter: 015400 - train loss: 0.676 - lr: 2.62e-04 - load time: 0.06 - gpu time: 158.01
# >>> Auto-saving checkpoint...
# iter: 015500 - valid loss: 0.715 - acc full seq: 0.3259 - acc per char: 0.8473
# iter: 015600 - train loss: 0.669 - lr: 2.61e-04 - load time: 0.66 - gpu time: 152.46
# >>> Auto-saving checkpoint...
# iter: 015800 - train loss: 0.678 - lr: 2.59e-04 - load time: 0.56 - gpu time: 160.15
# >>> Auto-saving checkpoint...
# iter: 016000 - train loss: 0.667 - lr: 2.58e-04 - load time: 0.07 - gpu time: 156.77
# >>> Auto-saving checkpoint...
# iter: 016000 - valid loss: 0.726 - acc full seq: 0.3281 - acc per char: 0.8383
# iter: 016200 - train loss: 0.678 - lr: 2.56e-04 - load time: 0.66 - gpu time: 156.56
# >>> Auto-saving checkpoint...
# iter: 016400 - train loss: 0.668 - lr: 2.55e-04 - load time: 0.06 - gpu time: 158.50
# >>> Auto-saving checkpoint...
# iter: 016500 - valid loss: 0.721 - acc full seq: 0.3627 - acc per char: 0.8482
# iter: 016600 - train loss: 0.679 - lr: 2.53e-04 - load time: 0.50 - gpu time: 155.65
# >>> Auto-saving checkpoint...
# iter: 016800 - train loss: 0.675 - lr: 2.52e-04 - load time: 0.07 - gpu time: 159.25
# >>> Auto-saving checkpoint...
# iter: 017000 - train loss: 0.670 - lr: 2.50e-04 - load time: 0.61 - gpu time: 152.56
# >>> Auto-saving checkpoint...
# iter: 017000 - valid loss: 0.722 - acc full seq: 0.3527 - acc per char: 0.8397
# iter: 017200 - train loss: 0.677 - lr: 2.49e-04 - load time: 0.08 - gpu time: 159.77
# >>> Auto-saving checkpoint...
# iter: 017400 - train loss: 0.668 - lr: 2.47e-04 - load time: 0.69 - gpu time: 154.23
# >>> Auto-saving checkpoint...
# iter: 017500 - valid loss: 0.720 - acc full seq: 0.3583 - acc per char: 0.8513
# iter: 017600 - train loss: 0.669 - lr: 2.46e-04 - load time: 0.07 - gpu time: 159.07
# >>> Auto-saving checkpoint...
# iter: 017800 - train loss: 0.672 - lr: 2.44e-04 - load time: 0.51 - gpu time: 155.44
# >>> Auto-saving checkpoint...
# iter: 018000 - train loss: 0.671 - lr: 2.42e-04 - load time: 0.07 - gpu time: 157.51
# >>> Auto-saving checkpoint...
# iter: 018000 - valid loss: 0.719 - acc full seq: 0.3672 - acc per char: 0.8471
# iter: 018200 - train loss: 0.666 - lr: 2.41e-04 - load time: 0.73 - gpu time: 157.46
# >>> Auto-saving checkpoint...
# iter: 018400 - train loss: 0.672 - lr: 2.39e-04 - load time: 0.07 - gpu time: 155.60
# >>> Auto-saving checkpoint...
# iter: 018500 - valid loss: 0.720 - acc full seq: 0.3650 - acc per char: 0.8483
# iter: 018600 - train loss: 0.671 - lr: 2.37e-04 - load time: 0.93 - gpu time: 158.69
# >>> Auto-saving checkpoint...
# iter: 018800 - train loss: 0.665 - lr: 2.36e-04 - load time: 0.06 - gpu time: 155.50
# >>> Auto-saving checkpoint...
# iter: 019000 - train loss: 0.660 - lr: 2.34e-04 - load time: 0.74 - gpu time: 158.74
# >>> Auto-saving checkpoint...
# iter: 019000 - valid loss: 0.716 - acc full seq: 0.3750 - acc per char: 0.8529
# iter: 019200 - train loss: 0.668 - lr: 2.32e-04 - load time: 0.71 - gpu time: 154.13
# >>> Auto-saving checkpoint...
# iter: 019400 - train loss: 0.670 - lr: 2.30e-04 - load time: 0.07 - gpu time: 157.46
# >>> Auto-saving checkpoint...
# iter: 019500 - valid loss: 0.715 - acc full seq: 0.3694 - acc per char: 0.8544
# iter: 019600 - train loss: 0.667 - lr: 2.29e-04 - load time: 0.79 - gpu time: 157.71
# >>> Auto-saving checkpoint...
# iter: 019800 - train loss: 0.672 - lr: 2.27e-04 - load time: 0.07 - gpu time: 159.27
# >>> Auto-saving checkpoint...
# iter: 020000 - train loss: 0.660 - lr: 2.25e-04 - load time: 0.82 - gpu time: 156.83
# >>> Auto-saving checkpoint...
# iter: 020000 - valid loss: 0.718 - acc full seq: 0.3895 - acc per char: 0.8663
# iter: 020200 - train loss: 0.666 - lr: 2.23e-04 - load time: 0.07 - gpu time: 156.89
# >>> Auto-saving checkpoint...
# iter: 020400 - train loss: 0.668 - lr: 2.21e-04 - load time: 1.12 - gpu time: 154.84
# >>> Auto-saving checkpoint...
# iter: 020500 - valid loss: 0.721 - acc full seq: 0.3482 - acc per char: 0.8594
# iter: 020600 - train loss: 0.663 - lr: 2.19e-04 - load time: 0.07 - gpu time: 157.03
# >>> Auto-saving checkpoint...
# iter: 020800 - train loss: 0.666 - lr: 2.18e-04 - load time: 0.67 - gpu time: 160.68
# >>> Auto-saving checkpoint...
# iter: 021000 - train loss: 0.656 - lr: 2.16e-04 - load time: 0.06 - gpu time: 155.72
# >>> Auto-saving checkpoint...
# iter: 021000 - valid loss: 0.715 - acc full seq: 0.3538 - acc per char: 0.8600
# iter: 021200 - train loss: 0.665 - lr: 2.14e-04 - load time: 0.84 - gpu time: 156.81
# >>> Auto-saving checkpoint...
# iter: 021400 - train loss: 0.658 - lr: 2.12e-04 - load time: 0.06 - gpu time: 156.40
# >>> Auto-saving checkpoint...
# iter: 021500 - valid loss: 0.710 - acc full seq: 0.3750 - acc per char: 0.8478
# iter: 021600 - train loss: 0.663 - lr: 2.10e-04 - load time: 0.86 - gpu time: 155.41
# >>> Auto-saving checkpoint...
# iter: 021800 - train loss: 0.664 - lr: 2.08e-04 - load time: 0.06 - gpu time: 157.62
# >>> Auto-saving checkpoint...
# iter: 022000 - train loss: 0.665 - lr: 2.06e-04 - load time: 0.59 - gpu time: 154.37
# >>> Auto-saving checkpoint...
# iter: 022000 - valid loss: 0.712 - acc full seq: 0.4007 - acc per char: 0.8568
# iter: 022200 - train loss: 0.660 - lr: 2.04e-04 - load time: 0.75 - gpu time: 160.57
# >>> Auto-saving checkpoint...
# iter: 022400 - train loss: 0.661 - lr: 2.02e-04 - load time: 0.06 - gpu time: 158.38
# >>> Auto-saving checkpoint...
# iter: 022500 - valid loss: 0.720 - acc full seq: 0.3795 - acc per char: 0.8591
# iter: 022600 - train loss: 0.663 - lr: 2.00e-04 - load time: 0.89 - gpu time: 155.32
# >>> Auto-saving checkpoint...
# iter: 022800 - train loss: 0.660 - lr: 1.98e-04 - load time: 0.07 - gpu time: 159.99
# >>> Auto-saving checkpoint...
# iter: 023000 - train loss: 0.656 - lr: 1.96e-04 - load time: 1.45 - gpu time: 152.51
# >>> Auto-saving checkpoint...
# iter: 023000 - valid loss: 0.721 - acc full seq: 0.3850 - acc per char: 0.8493
# iter: 023200 - train loss: 0.667 - lr: 1.94e-04 - load time: 0.06 - gpu time: 157.19
# >>> Auto-saving checkpoint...
# iter: 023400 - train loss: 0.657 - lr: 1.92e-04 - load time: 0.57 - gpu time: 156.47
# >>> Auto-saving checkpoint...
# iter: 023500 - valid loss: 0.711 - acc full seq: 0.3951 - acc per char: 0.8653
# iter: 023600 - train loss: 0.668 - lr: 1.90e-04 - load time: 0.07 - gpu time: 158.12
# >>> Auto-saving checkpoint...
# iter: 023800 - train loss: 0.654 - lr: 1.88e-04 - load time: 0.65 - gpu time: 155.91
# >>> Auto-saving checkpoint...
# iter: 024000 - train loss: 0.666 - lr: 1.86e-04 - load time: 0.06 - gpu time: 158.61
# >>> Auto-saving checkpoint...
# iter: 024000 - valid loss: 0.714 - acc full seq: 0.3862 - acc per char: 0.8585
# iter: 024200 - train loss: 0.651 - lr: 1.84e-04 - load time: 0.52 - gpu time: 155.75
# >>> Auto-saving checkpoint...
# iter: 024400 - train loss: 0.667 - lr: 1.82e-04 - load time: 0.07 - gpu time: 157.52
# >>> Auto-saving checkpoint...
# iter: 024500 - valid loss: 0.706 - acc full seq: 0.3817 - acc per char: 0.8606
# iter: 024600 - train loss: 0.663 - lr: 1.80e-04 - load time: 0.77 - gpu time: 157.03
# >>> Auto-saving checkpoint...
# iter: 024800 - train loss: 0.656 - lr: 1.78e-04 - load time: 0.07 - gpu time: 156.43
# >>> Auto-saving checkpoint...
# iter: 025000 - train loss: 0.659 - lr: 1.76e-04 - load time: 1.36 - gpu time: 156.35
# >>> Auto-saving checkpoint...
# iter: 025000 - valid loss: 0.715 - acc full seq: 0.3839 - acc per char: 0.8604
# iter: 025200 - train loss: 0.661 - lr: 1.74e-04 - load time: 0.80 - gpu time: 157.83
# >>> Auto-saving checkpoint...
# iter: 025400 - train loss: 0.647 - lr: 1.72e-04 - load time: 0.07 - gpu time: 153.95
# >>> Auto-saving checkpoint...
# iter: 025500 - valid loss: 0.713 - acc full seq: 0.4208 - acc per char: 0.8694
# iter: 025600 - train loss: 0.668 - lr: 1.70e-04 - load time: 0.41 - gpu time: 161.25
# >>> Auto-saving checkpoint...
# iter: 025800 - train loss: 0.661 - lr: 1.68e-04 - load time: 0.06 - gpu time: 157.73
# >>> Auto-saving checkpoint...
# iter: 026000 - train loss: 0.656 - lr: 1.66e-04 - load time: 0.79 - gpu time: 154.66
# >>> Auto-saving checkpoint...
# iter: 026000 - valid loss: 0.720 - acc full seq: 0.3996 - acc per char: 0.8547
# iter: 026200 - train loss: 0.654 - lr: 1.64e-04 - load time: 0.07 - gpu time: 157.36
# >>> Auto-saving checkpoint...
# iter: 026400 - train loss: 0.662 - lr: 1.61e-04 - load time: 0.94 - gpu time: 155.95
# >>> Auto-saving checkpoint...
# iter: 026500 - valid loss: 0.715 - acc full seq: 0.4007 - acc per char: 0.8589
# iter: 026600 - train loss: 0.657 - lr: 1.59e-04 - load time: 0.07 - gpu time: 155.44
# >>> Auto-saving checkpoint...
# iter: 026800 - train loss: 0.659 - lr: 1.57e-04 - load time: 0.72 - gpu time: 158.04
# >>> Auto-saving checkpoint...
# iter: 027000 - train loss: 0.650 - lr: 1.55e-04 - load time: 0.07 - gpu time: 154.79
# >>> Auto-saving checkpoint...
# iter: 027000 - valid loss: 0.713 - acc full seq: 0.3917 - acc per char: 0.8671
# iter: 027200 - train loss: 0.663 - lr: 1.53e-04 - load time: 0.86 - gpu time: 159.21
# >>> Auto-saving checkpoint...
# iter: 027400 - train loss: 0.656 - lr: 1.51e-04 - load time: 0.07 - gpu time: 154.01
# >>> Auto-saving checkpoint...
# iter: 027500 - valid loss: 0.703 - acc full seq: 0.3806 - acc per char: 0.8631
# iter: 027600 - train loss: 0.667 - lr: 1.49e-04 - load time: 0.60 - gpu time: 159.30
# >>> Auto-saving checkpoint...
# iter: 027800 - train loss: 0.652 - lr: 1.47e-04 - load time: 0.07 - gpu time: 156.55
# >>> Auto-saving checkpoint...
# iter: 028000 - train loss: 0.655 - lr: 1.45e-04 - load time: 0.85 - gpu time: 155.13
# >>> Auto-saving checkpoint...
# iter: 028000 - valid loss: 0.715 - acc full seq: 0.4141 - acc per char: 0.8670
# iter: 028200 - train loss: 0.655 - lr: 1.43e-04 - load time: 0.07 - gpu time: 158.77
# >>> Auto-saving checkpoint...
# iter: 028400 - train loss: 0.649 - lr: 1.41e-04 - load time: 0.41 - gpu time: 157.36
# >>> Auto-saving checkpoint...
# iter: 028500 - valid loss: 0.711 - acc full seq: 0.4062 - acc per char: 0.8661
# iter: 028600 - train loss: 0.664 - lr: 1.38e-04 - load time: 0.67 - gpu time: 156.34
# >>> Auto-saving checkpoint...
# iter: 028800 - train loss: 0.654 - lr: 1.36e-04 - load time: 0.06 - gpu time: 155.67
# >>> Auto-saving checkpoint...
# iter: 029000 - train loss: 0.659 - lr: 1.34e-04 - load time: 0.64 - gpu time: 158.05
# >>> Auto-saving checkpoint...
# iter: 029000 - valid loss: 0.712 - acc full seq: 0.4007 - acc per char: 0.8573
# iter: 029200 - train loss: 0.651 - lr: 1.32e-04 - load time: 0.06 - gpu time: 155.07
# >>> Auto-saving checkpoint...
# iter: 029400 - train loss: 0.658 - lr: 1.30e-04 - load time: 0.57 - gpu time: 159.61
# >>> Auto-saving checkpoint...
# iter: 029500 - valid loss: 0.713 - acc full seq: 0.4196 - acc per char: 0.8684
# iter: 029600 - train loss: 0.658 - lr: 1.28e-04 - load time: 0.07 - gpu time: 155.87
# >>> Auto-saving checkpoint...
# iter: 029800 - train loss: 0.651 - lr: 1.26e-04 - load time: 0.41 - gpu time: 158.55
# >>> Auto-saving checkpoint...
# iter: 030000 - train loss: 0.651 - lr: 1.24e-04 - load time: 0.07 - gpu time: 156.27
# >>> Auto-saving checkpoint...
# iter: 030000 - valid loss: 0.719 - acc full seq: 0.4263 - acc per char: 0.8752
# iter: 030200 - train loss: 0.661 - lr: 1.22e-04 - load time: 0.43 - gpu time: 157.70
# >>> Auto-saving checkpoint...
# iter: 030400 - train loss: 0.646 - lr: 1.20e-04 - load time: 0.07 - gpu time: 154.52
# >>> Auto-saving checkpoint...
# iter: 030500 - valid loss: 0.714 - acc full seq: 0.4342 - acc per char: 0.8724
# iter: 030600 - train loss: 0.657 - lr: 1.18e-04 - load time: 0.74 - gpu time: 159.79
# >>> Auto-saving checkpoint...
# iter: 030800 - train loss: 0.651 - lr: 1.16e-04 - load time: 0.07 - gpu time: 154.72
# >>> Auto-saving checkpoint...
# iter: 031000 - train loss: 0.664 - lr: 1.14e-04 - load time: 0.57 - gpu time: 157.23
# >>> Auto-saving checkpoint...
# iter: 031000 - valid loss: 0.718 - acc full seq: 0.4219 - acc per char: 0.8717
# iter: 031200 - train loss: 0.649 - lr: 1.12e-04 - load time: 0.07 - gpu time: 157.12
# >>> Auto-saving checkpoint...
# iter: 031400 - train loss: 0.657 - lr: 1.10e-04 - load time: 0.68 - gpu time: 156.73
# >>> Auto-saving checkpoint...
# iter: 031500 - valid loss: 0.714 - acc full seq: 0.4107 - acc per char: 0.8594
# iter: 031600 - train loss: 0.650 - lr: 1.08e-04 - load time: 0.46 - gpu time: 157.77
# >>> Auto-saving checkpoint...
# iter: 031800 - train loss: 0.651 - lr: 1.06e-04 - load time: 0.06 - gpu time: 157.59
# >>> Auto-saving checkpoint...
# iter: 032000 - train loss: 0.652 - lr: 1.04e-04 - load time: 1.05 - gpu time: 155.88
# >>> Auto-saving checkpoint...
# iter: 032000 - valid loss: 0.710 - acc full seq: 0.4408 - acc per char: 0.8826
# iter: 032200 - train loss: 0.652 - lr: 1.02e-04 - load time: 0.07 - gpu time: 157.45
# >>> Auto-saving checkpoint...
# iter: 032400 - train loss: 0.652 - lr: 9.97e-05 - load time: 0.70 - gpu time: 157.46
# >>> Auto-saving checkpoint...
# iter: 032500 - valid loss: 0.712 - acc full seq: 0.4342 - acc per char: 0.8666
# iter: 032600 - train loss: 0.655 - lr: 9.77e-05 - load time: 0.06 - gpu time: 156.53
# >>> Auto-saving checkpoint...
# iter: 032800 - train loss: 0.653 - lr: 9.57e-05 - load time: 0.92 - gpu time: 156.33
# >>> Auto-saving checkpoint...
# iter: 033000 - train loss: 0.652 - lr: 9.38e-05 - load time: 0.06 - gpu time: 161.09
# >>> Auto-saving checkpoint...
# iter: 033000 - valid loss: 0.714 - acc full seq: 0.4330 - acc per char: 0.8791
# iter: 033200 - train loss: 0.657 - lr: 9.19e-05 - load time: 0.67 - gpu time: 154.40
# >>> Auto-saving checkpoint...
# iter: 033400 - train loss: 0.650 - lr: 8.99e-05 - load time: 0.08 - gpu time: 155.18
# >>> Auto-saving checkpoint...
# iter: 033500 - valid loss: 0.708 - acc full seq: 0.4353 - acc per char: 0.8730
# iter: 033600 - train loss: 0.644 - lr: 8.80e-05 - load time: 0.82 - gpu time: 154.79
# >>> Auto-saving checkpoint...
# iter: 033800 - train loss: 0.647 - lr: 8.61e-05 - load time: 0.07 - gpu time: 158.12
# >>> Auto-saving checkpoint...
# iter: 034000 - train loss: 0.661 - lr: 8.42e-05 - load time: 0.60 - gpu time: 160.17
# >>> Auto-saving checkpoint...
# iter: 034000 - valid loss: 0.712 - acc full seq: 0.4241 - acc per char: 0.8772
# iter: 034200 - train loss: 0.645 - lr: 8.24e-05 - load time: 0.07 - gpu time: 156.27
# >>> Auto-saving checkpoint...
# iter: 034400 - train loss: 0.659 - lr: 8.05e-05 - load time: 0.41 - gpu time: 157.08
# >>> Auto-saving checkpoint...
# iter: 034500 - valid loss: 0.708 - acc full seq: 0.4118 - acc per char: 0.8659
# iter: 034600 - train loss: 0.648 - lr: 7.86e-05 - load time: 0.71 - gpu time: 156.64
# >>> Auto-saving checkpoint...
# iter: 034800 - train loss: 0.650 - lr: 7.68e-05 - load time: 0.07 - gpu time: 157.29
# >>> Auto-saving checkpoint...
# iter: 035000 - train loss: 0.657 - lr: 7.50e-05 - load time: 0.60 - gpu time: 157.52
# >>> Auto-saving checkpoint...
# iter: 035000 - valid loss: 0.704 - acc full seq: 0.4364 - acc per char: 0.8695
# iter: 035200 - train loss: 0.648 - lr: 7.32e-05 - load time: 0.07 - gpu time: 152.25
# >>> Auto-saving checkpoint...
# iter: 035400 - train loss: 0.654 - lr: 7.14e-05 - load time: 0.86 - gpu time: 160.70
# >>> Auto-saving checkpoint...
# iter: 035500 - valid loss: 0.708 - acc full seq: 0.4230 - acc per char: 0.8730
# iter: 035600 - train loss: 0.653 - lr: 6.96e-05 - load time: 0.07 - gpu time: 158.23
# >>> Auto-saving checkpoint...
# iter: 035800 - train loss: 0.647 - lr: 6.79e-05 - load time: 0.54 - gpu time: 155.82
# >>> Auto-saving checkpoint...
# iter: 036000 - train loss: 0.651 - lr: 6.61e-05 - load time: 0.07 - gpu time: 156.10
# >>> Auto-saving checkpoint...
# iter: 036000 - valid loss: 0.716 - acc full seq: 0.4509 - acc per char: 0.8723
# iter: 036200 - train loss: 0.651 - lr: 6.44e-05 - load time: 0.73 - gpu time: 157.92
# >>> Auto-saving checkpoint...
# iter: 036400 - train loss: 0.649 - lr: 6.27e-05 - load time: 0.07 - gpu time: 157.37
# >>> Auto-saving checkpoint...
# iter: 036500 - valid loss: 0.707 - acc full seq: 0.4353 - acc per char: 0.8792
# iter: 036600 - train loss: 0.647 - lr: 6.10e-05 - load time: 0.91 - gpu time: 160.22
# >>> Auto-saving checkpoint...
# iter: 036800 - train loss: 0.650 - lr: 5.93e-05 - load time: 0.07 - gpu time: 153.71
# >>> Auto-saving checkpoint...
# iter: 037000 - train loss: 0.640 - lr: 5.76e-05 - load time: 0.38 - gpu time: 157.99
# >>> Auto-saving checkpoint...
# iter: 037000 - valid loss: 0.709 - acc full seq: 0.4364 - acc per char: 0.8711
# iter: 037200 - train loss: 0.655 - lr: 5.60e-05 - load time: 0.07 - gpu time: 154.73
# >>> Auto-saving checkpoint...
# iter: 037400 - train loss: 0.649 - lr: 5.44e-05 - load time: 0.73 - gpu time: 155.88
# >>> Auto-saving checkpoint...
# iter: 037500 - valid loss: 0.706 - acc full seq: 0.4219 - acc per char: 0.8759
# iter: 037600 - train loss: 0.653 - lr: 5.28e-05 - load time: 0.07 - gpu time: 158.38
# >>> Auto-saving checkpoint...
# iter: 037800 - train loss: 0.648 - lr: 5.12e-05 - load time: 0.79 - gpu time: 155.64
# >>> Auto-saving checkpoint...
# iter: 038000 - train loss: 0.654 - lr: 4.96e-05 - load time: 0.65 - gpu time: 156.41
# >>> Auto-saving checkpoint...
# iter: 038000 - valid loss: 0.705 - acc full seq: 0.4375 - acc per char: 0.8834
# iter: 038200 - train loss: 0.644 - lr: 4.81e-05 - load time: 0.07 - gpu time: 156.94
# >>> Auto-saving checkpoint...
# iter: 038400 - train loss: 0.655 - lr: 4.66e-05 - load time: 0.96 - gpu time: 158.78
# >>> Auto-saving checkpoint...
# iter: 038500 - valid loss: 0.713 - acc full seq: 0.4408 - acc per char: 0.8733
# iter: 038600 - train loss: 0.649 - lr: 4.50e-05 - load time: 0.06 - gpu time: 156.33
# >>> Auto-saving checkpoint...
# iter: 038800 - train loss: 0.641 - lr: 4.36e-05 - load time: 0.65 - gpu time: 154.12
# >>> Auto-saving checkpoint...
# iter: 039000 - train loss: 0.657 - lr: 4.21e-05 - load time: 0.07 - gpu time: 160.84
# >>> Auto-saving checkpoint...
# iter: 039000 - valid loss: 0.703 - acc full seq: 0.4319 - acc per char: 0.8692
# iter: 039200 - train loss: 0.649 - lr: 4.06e-05 - load time: 0.82 - gpu time: 157.40
# >>> Auto-saving checkpoint...
# iter: 039400 - train loss: 0.649 - lr: 3.92e-05 - load time: 0.07 - gpu time: 153.62
# >>> Auto-saving checkpoint...
# iter: 039500 - valid loss: 0.712 - acc full seq: 0.4587 - acc per char: 0.8815
# iter: 039600 - train loss: 0.644 - lr: 3.78e-05 - load time: 0.80 - gpu time: 156.05
# >>> Auto-saving checkpoint...
# iter: 039800 - train loss: 0.652 - lr: 3.64e-05 - load time: 0.07 - gpu time: 156.48
# >>> Auto-saving checkpoint...
# iter: 040000 - train loss: 0.645 - lr: 3.51e-05 - load time: 0.58 - gpu time: 158.88
# >>> Auto-saving checkpoint...
# iter: 040000 - valid loss: 0.702 - acc full seq: 0.4308 - acc per char: 0.8786
# iter: 040200 - train loss: 0.652 - lr: 3.38e-05 - load time: 0.06 - gpu time: 155.60
# >>> Auto-saving checkpoint...
# iter: 040400 - train loss: 0.653 - lr: 3.24e-05 - load time: 0.41 - gpu time: 156.77
# >>> Auto-saving checkpoint...
# iter: 040500 - valid loss: 0.713 - acc full seq: 0.4542 - acc per char: 0.8719
# iter: 040600 - train loss: 0.647 - lr: 3.12e-05 - load time: 0.07 - gpu time: 157.16
# >>> Auto-saving checkpoint...
# iter: 040800 - train loss: 0.651 - lr: 2.99e-05 - load time: 0.72 - gpu time: 159.65
# >>> Auto-saving checkpoint...
# iter: 041000 - train loss: 0.647 - lr: 2.86e-05 - load time: 0.76 - gpu time: 155.06
# >>> Auto-saving checkpoint...
# iter: 041000 - valid loss: 0.714 - acc full seq: 0.4475 - acc per char: 0.8681
# iter: 041200 - train loss: 0.643 - lr: 2.74e-05 - load time: 0.07 - gpu time: 157.20
# >>> Auto-saving checkpoint...
# iter: 041400 - train loss: 0.650 - lr: 2.62e-05 - load time: 0.68 - gpu time: 154.40
# >>> Auto-saving checkpoint...
# iter: 041500 - valid loss: 0.723 - acc full seq: 0.4576 - acc per char: 0.8829
# iter: 041600 - train loss: 0.644 - lr: 2.51e-05 - load time: 0.07 - gpu time: 154.97
# >>> Auto-saving checkpoint...
# iter: 041800 - train loss: 0.654 - lr: 2.39e-05 - load time: 0.57 - gpu time: 159.06
# >>> Auto-saving checkpoint...
# iter: 042000 - train loss: 0.660 - lr: 2.28e-05 - load time: 0.07 - gpu time: 159.22
# >>> Auto-saving checkpoint...
# iter: 042000 - valid loss: 0.716 - acc full seq: 0.4487 - acc per char: 0.8824
# iter: 042200 - train loss: 0.643 - lr: 2.17e-05 - load time: 0.59 - gpu time: 154.30
# >>> Auto-saving checkpoint...
# iter: 042400 - train loss: 0.642 - lr: 2.06e-05 - load time: 0.06 - gpu time: 154.57
# >>> Auto-saving checkpoint...
# iter: 042500 - valid loss: 0.701 - acc full seq: 0.4531 - acc per char: 0.8712
# iter: 042600 - train loss: 0.662 - lr: 1.96e-05 - load time: 0.80 - gpu time: 159.14
# >>> Auto-saving checkpoint...
# iter: 042800 - train loss: 0.643 - lr: 1.86e-05 - load time: 0.08 - gpu time: 155.29
# >>> Auto-saving checkpoint...
# iter: 043000 - train loss: 0.645 - lr: 1.76e-05 - load time: 0.77 - gpu time: 153.84
# >>> Auto-saving checkpoint...
# iter: 043000 - valid loss: 0.709 - acc full seq: 0.4509 - acc per char: 0.8733
# iter: 043200 - train loss: 0.648 - lr: 1.66e-05 - load time: 0.08 - gpu time: 162.20
# >>> Auto-saving checkpoint...
# iter: 043400 - train loss: 0.651 - lr: 1.56e-05 - load time: 0.75 - gpu time: 157.78
# >>> Auto-saving checkpoint...
# iter: 043500 - valid loss: 0.708 - acc full seq: 0.4520 - acc per char: 0.8733
# iter: 043600 - train loss: 0.648 - lr: 1.47e-05 - load time: 0.08 - gpu time: 155.08
# >>> Auto-saving checkpoint...
# iter: 043800 - train loss: 0.654 - lr: 1.38e-05 - load time: 0.79 - gpu time: 154.76
# >>> Auto-saving checkpoint...
# iter: 044000 - train loss: 0.642 - lr: 1.30e-05 - load time: 1.01 - gpu time: 158.14
# >>> Auto-saving checkpoint...
# iter: 044000 - valid loss: 0.708 - acc full seq: 0.4565 - acc per char: 0.8851
# iter: 044200 - train loss: 0.643 - lr: 1.21e-05 - load time: 0.07 - gpu time: 156.28
# >>> Auto-saving checkpoint...
# iter: 044400 - train loss: 0.652 - lr: 1.13e-05 - load time: 0.84 - gpu time: 159.29
# >>> Auto-saving checkpoint...
# iter: 044500 - valid loss: 0.705 - acc full seq: 0.4498 - acc per char: 0.8760
# iter: 044600 - train loss: 0.646 - lr: 1.05e-05 - load time: 0.08 - gpu time: 158.54
# >>> Auto-saving checkpoint...
# iter: 044800 - train loss: 0.642 - lr: 9.77e-06 - load time: 0.84 - gpu time: 154.59
# >>> Auto-saving checkpoint...
# iter: 045000 - train loss: 0.650 - lr: 9.04e-06 - load time: 0.07 - gpu time: 159.96
# >>> Auto-saving checkpoint...
# iter: 045000 - valid loss: 0.711 - acc full seq: 0.4408 - acc per char: 0.8802
# iter: 045200 - train loss: 0.649 - lr: 8.34e-06 - load time: 0.74 - gpu time: 157.88
# >>> Auto-saving checkpoint...
# iter: 045400 - train loss: 0.650 - lr: 7.67e-06 - load time: 0.07 - gpu time: 158.16
# >>> Auto-saving checkpoint...
# iter: 045500 - valid loss: 0.719 - acc full seq: 0.4632 - acc per char: 0.8829
# iter: 045600 - train loss: 0.643 - lr: 7.02e-06 - load time: 0.73 - gpu time: 153.26
# >>> Auto-saving checkpoint...
# iter: 045800 - train loss: 0.644 - lr: 6.40e-06 - load time: 0.07 - gpu time: 155.98
# >>> Auto-saving checkpoint...
# iter: 046000 - train loss: 0.650 - lr: 5.81e-06 - load time: 0.60 - gpu time: 159.23
# >>> Auto-saving checkpoint...
# iter: 046000 - valid loss: 0.706 - acc full seq: 0.4531 - acc per char: 0.8766
# iter: 046200 - train loss: 0.645 - lr: 5.25e-06 - load time: 0.07 - gpu time: 155.09
# >>> Auto-saving checkpoint...
# iter: 046400 - train loss: 0.652 - lr: 4.71e-06 - load time: 0.77 - gpu time: 157.23
# >>> Auto-saving checkpoint...
# iter: 046500 - valid loss: 0.708 - acc full seq: 0.4632 - acc per char: 0.8827
# iter: 046600 - train loss: 0.649 - lr: 4.20e-06 - load time: 0.07 - gpu time: 157.21
# >>> Auto-saving checkpoint...
# iter: 046800 - train loss: 0.638 - lr: 3.73e-06 - load time: 0.51 - gpu time: 157.16
# >>> Auto-saving checkpoint...
# iter: 047000 - train loss: 0.652 - lr: 3.28e-06 - load time: 0.07 - gpu time: 154.65
# >>> Auto-saving checkpoint...
# iter: 047000 - valid loss: 0.707 - acc full seq: 0.4520 - acc per char: 0.8788
# iter: 047200 - train loss: 0.644 - lr: 2.86e-06 - load time: 0.81 - gpu time: 153.49
# >>> Auto-saving checkpoint...
# iter: 047400 - train loss: 0.652 - lr: 2.46e-06 - load time: 0.74 - gpu time: 159.70
# >>> Auto-saving checkpoint...
# iter: 047500 - valid loss: 0.704 - acc full seq: 0.4475 - acc per char: 0.8773
# iter: 047600 - train loss: 0.646 - lr: 2.10e-06 - load time: 0.08 - gpu time: 158.12
# >>> Auto-saving checkpoint...
# iter: 047800 - train loss: 0.653 - lr: 1.77e-06 - load time: 0.42 - gpu time: 159.21
# >>> Auto-saving checkpoint...
# iter: 048000 - train loss: 0.642 - lr: 1.46e-06 - load time: 0.08 - gpu time: 158.08
# >>> Auto-saving checkpoint...
# iter: 048000 - valid loss: 0.714 - acc full seq: 0.4420 - acc per char: 0.8780
# iter: 048200 - train loss: 0.648 - lr: 1.18e-06 - load time: 0.81 - gpu time: 153.56
# >>> Auto-saving checkpoint...
# iter: 048400 - train loss: 0.646 - lr: 9.35e-07 - load time: 0.07 - gpu time: 156.56
# >>> Auto-saving checkpoint...
# iter: 048500 - valid loss: 0.705 - acc full seq: 0.4554 - acc per char: 0.8801
# iter: 048600 - train loss: 0.653 - lr: 7.16e-07 - load time: 0.77 - gpu time: 159.92
# >>> Auto-saving checkpoint...
# iter: 048800 - train loss: 0.651 - lr: 5.26e-07 - load time: 0.07 - gpu time: 155.56
# >>> Auto-saving checkpoint...
# iter: 049000 - train loss: 0.642 - lr: 3.66e-07 - load time: 0.41 - gpu time: 157.13
# >>> Auto-saving checkpoint...
# iter: 049000 - valid loss: 0.701 - acc full seq: 0.4475 - acc per char: 0.8800
# iter: 049200 - train loss: 0.648 - lr: 2.35e-07 - load time: 0.09 - gpu time: 153.32
# >>> Auto-saving checkpoint...
# iter: 049400 - train loss: 0.651 - lr: 1.32e-07 - load time: 0.74 - gpu time: 160.19
# >>> Auto-saving checkpoint...
# iter: 049500 - valid loss: 0.706 - acc full seq: 0.4464 - acc per char: 0.8783
# iter: 049600 - train loss: 0.647 - lr: 5.94e-08 - load time: 0.08 - gpu time: 155.42
# >>> Auto-saving checkpoint...
# iter: 049800 - train loss: 0.642 - lr: 1.57e-08 - load time: 0.51 - gpu time: 154.53
# >>> Auto-saving checkpoint...
# iter: 050000 - train loss: 0.652 - lr: 1.20e-09 - load time: 0.08 - gpu time: 160.64
# >>> Auto-saving checkpoint...
# iter: 050000 - valid loss: 0.707 - acc full seq: 0.4487 - acc per char: 0.8829
# >>> Saving final checkpoint...
#
# Training completed successfully!

# %% [markdown]
# ## 6. Post-Training: Visualize Metrics

# %%
import os
import re
import pandas as pd
import matplotlib.pyplot as plt

log_dir = config["trainer"]["log"]
metrics_records = []

log_file_candidates = [
    log_dir,
    log_dir + ".log",
    os.path.join(log_dir, "train.log"),
    os.path.join(checkpoint_dir_abs, "train.log"),
]

log_content = None
for candidate in log_file_candidates:
    if os.path.isfile(candidate):
        with open(candidate, "r", encoding="utf-8") as f:
            log_content = f.read()
        print(f"Found training log at: {candidate}")
        break


# =====================================================
# 1️⃣ PARSE TRAIN LOSS FROM LOG
# =====================================================
if log_content:
    train_pattern = re.compile(
        r"iter:\s*(\d+)\s*-\s*train loss:\s*([\d.]+)",
        re.IGNORECASE
    )

    matches = train_pattern.findall(log_content)

    for iter_str, loss_str in matches:
        metrics_records.append({
            "iteration": int(iter_str),
            "loss": float(loss_str)
        })


# =====================================================
# 2️⃣ FALLBACK: trainer.train_losses
#    DẠNG: [(iter, loss), (iter, loss), ...]
# =====================================================
if not metrics_records and hasattr(trainer, "train_losses") and trainer.train_losses:

    print("Using trainer.train_losses as fallback")

    for item in trainer.train_losses:

        # Nếu là tuple (iteration, loss)
        if isinstance(item, (list, tuple)) and len(item) == 2:
            iteration, loss = item
        else:
            continue

        try:
            metrics_records.append({
                "iteration": int(iteration),
                "loss": float(loss)
            })
        except:
            continue


# =====================================================
# 3️⃣ CREATE DATAFRAME
# =====================================================
if metrics_records:

    df_metrics = (
        pd.DataFrame(metrics_records)
        .drop_duplicates(subset="iteration")
        .sort_values("iteration")
        .reset_index(drop=True)
    )

    df_metrics["iteration"] = pd.to_numeric(df_metrics["iteration"], errors="coerce")
    df_metrics["loss"] = pd.to_numeric(df_metrics["loss"], errors="coerce")

    df_metrics = df_metrics.dropna()

    # =====================================================
    # 4️⃣ PLOT
    # =====================================================
    fig, ax = plt.subplots(figsize=(12, 5))

    ax.plot(
        df_metrics["iteration"],
        df_metrics["loss"],
        linewidth=1,
        alpha=0.7,
        label="Train Loss"
    )

    window = max(1, len(df_metrics) // 20)

    if len(df_metrics) > window:
        smoothed = df_metrics["loss"].rolling(
            window=window,
            min_periods=1
        ).mean()

        ax.plot(
            df_metrics["iteration"],
            smoothed,
            linewidth=2,
            color="red",
            label=f"Smoothed (w={window})"
        )

    ax.set_xlabel("Iteration")
    ax.set_ylabel("Loss")
    ax.set_title("Training Loss Curve")
    ax.legend()
    ax.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig(os.path.join(checkpoint_dir_abs, "loss_curve.png"), dpi=150)
    plt.show()

    # =====================================================
    # 5️⃣ SAVE CSV
    # =====================================================
    metrics_csv_path = os.path.join(checkpoint_dir_abs, "metrics.csv")
    df_metrics.to_csv(metrics_csv_path, index=False)

    print(f"Metrics saved to: {metrics_csv_path}")
    print("\nMetrics summary:")
    print(df_metrics.describe())

else:
    print("No training metrics found.")
    df_metrics = pd.DataFrame(columns=["iteration", "loss"])
    metrics_csv_path = os.path.join(checkpoint_dir_abs, "metrics.csv")
    df_metrics.to_csv(metrics_csv_path, index=False)
    print(f"Empty metrics CSV saved to: {metrics_csv_path}")
# Out:
# Found training log at: /kaggle/working/models/baseline/training_log
# Metrics saved to: /kaggle/working/models/baseline/metrics.csv
#
# Metrics summary:
#           iteration        loss
# count    250.000000  250.000000
# mean   25100.000000    0.686960
# std    14462.595433    0.083585
# min      200.000000    0.638000
# 25%    12650.000000    0.651000
# 50%    25100.000000    0.660000
# 75%    37550.000000    0.681750
# max    50000.000000    1.366000

# %%
def _resolve_image_path(image_path: str, image_root: str) -> str:
    """Ghép đường dẫn ảnh an toàn, tránh lặp data/data."""
    rel_path = image_path
    if rel_path.startswith("data/"):
        rel_path = rel_path[len("data/"):]
    return os.path.join(os.path.abspath(image_root), rel_path)

# %%
def compute_cer(predictions: list, ground_truths: list) -> float:
    """Compute Character Error Rate."""
    assert len(predictions) == len(ground_truths)
    filtered_preds, filtered_gts = [], []
    for pred, gt in zip(predictions, ground_truths):
        gt_clean = gt.strip()
        pred_clean = pred.strip()
        if len(gt_clean) == 0:
            continue
        filtered_preds.append(pred_clean)
        filtered_gts.append(gt_clean)
    if len(filtered_gts) == 0:
        return 0.0
    return float(jiwer.cer(filtered_gts, filtered_preds))

# %%
def compute_wer(predictions: list, ground_truths: list) -> float:
    """Compute WER (error rate at token level)."""
    assert len(predictions) == len(ground_truths)
    filtered_preds, filtered_gts = [], []
    for pred, gt in zip(predictions, ground_truths):
        gt_clean = gt.strip()
        pred_clean = pred.strip()
        if len(gt_clean) == 0 or len(gt_clean.split()) == 0:
            continue
        filtered_preds.append(pred_clean)
        filtered_gts.append(gt_clean)
    if len(filtered_gts) == 0:
        return 0.0
    return float(jiwer.wer(filtered_gts, filtered_preds))

# %%
best_model_path = config["trainer"]["export"]

if os.path.isfile(best_model_path):
    print(f"Loading best model from: {best_model_path}")

    pred_config = Cfg.load_config_from_name("vgg_seq2seq")
    pred_config["dataset"]["image_height"] = CONFIG["image_height"]
    pred_config["dataset"]["image_max_width"] = CONFIG["image_max_width"]
    pred_config["dataset"]["image_min_width"] = CONFIG["image_min_width"]
    pred_config["weights"] = best_model_path
    pred_config["device"] = CONFIG["device"]

    predictor = Predictor(pred_config)
    print("Predictor initialized.")

    predictions = []
    ground_truths = []
    image_paths = []
    errors=[]

    test_image_root = os.path.abspath(CONFIG["image_root"])
    use_grayscale = CONFIG["grayscale"]

    for img_rel_path, gt_text in test_data:
        img_full_path = _resolve_image_path(img_rel_path, CONFIG["image_root"])

        try:
            img = Image.open(img_full_path)
            if use_grayscale:
                img = img.convert("L").convert("RGB")
            else:
                img = img.convert("RGB")
            pred_text = predictor.predict(img)
            predictions.append(pred_text)
            ground_truths.append(gt_text)
            image_paths.append(img_rel_path)
        except FileNotFoundError:
            errors.append((img_rel_path, "FileNotFoundError"))
        except Exception as e:
            errors.append((img_rel_path, str(e)))

    if predictions:
        test_cer = compute_cer(predictions, ground_truths)
        test_wer = compute_wer(predictions, ground_truths)

        df_results = pd.DataFrame({
            "image": image_paths,
            "ground_truth": ground_truths,
            "prediction": predictions,
            "match": [p.strip() == g.strip() for p, g in zip(predictions, ground_truths)],
        })
        df_results["exact_match"] = df_results["prediction"].str.strip() == df_results["ground_truth"].str.strip()

        exact_match = int(df_results["exact_match"].sum())
        exact_match_pct = exact_match / len(df_results) * 100

        print(f"\nTest Evaluation ({len(df_results):,} samples):")
        print(f"  CER: {test_cer:.4f} ({test_cer * 100:.2f}%)")
        print(f"  WER: {test_wer:.4f} ({test_wer * 100:.2f}%)")
        print(f"  Exact matches: {exact_match}/{len(df_results)} ({exact_match_pct:.2f}%)")
        print(f"  Prediction errors: {len(errors):,}")
        if use_grayscale:
            print("  Grayscale: enabled (L -> RGB)")

        test_eval_csv = os.path.join(checkpoint_dir_abs, "test_predictions.csv")
        df_results.to_csv(test_eval_csv, index=False, encoding="utf-8")
        print(f"\nĐã lưu dự đoán test tại: {test_eval_csv}")

        if errors:
            print("\n5 lỗi đầu tiên:")
            for p, e in errors[:5]:
                print(f"  {p}: {e}")
    else:
        print("Không tạo được dự đoán hợp lệ trên test set. Hãy kiểm tra đường dẫn ảnh.")
else:
    print(f"Không tìm thấy best model tại: {best_model_path}")
    print("Bỏ qua test evaluation. Hãy chạy lại cell này sau khi train xong.")
# Out:
# Loading best model from: /kaggle/working/models/baseline/best_model.pth
# Predictor initialized.
#
# Test Evaluation (1,637 samples):
#   CER: 0.0273 (2.73%)
#   WER: 0.0730 (7.30%)
#   Exact matches: 826/1637 (50.46%)
#   Prediction errors: 0
#   Grayscale: enabled (L -> RGB)
#
# Đã lưu dự đoán test tại: /kaggle/working/models/baseline/test_predictions.csv
